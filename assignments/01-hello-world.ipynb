// %% [markdown]
// # Assignment 1: Hello World
//
// Welcome to AP Computer Science A!
//
// This is your first Java notebook.
//
// ➡️ Run the code cell below to print your first message!

// %%
System.out.println("Hello, AP CSA world!");

// %% [markdown]
// ✅ **Your task:** Modify the code above to print **your name** instead of 'world'.
// Then click *Run* (the ▶ button at the top) to test it!
